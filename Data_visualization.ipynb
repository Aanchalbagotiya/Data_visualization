# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/content/diabetes.csv')

# %%
data.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50     True
# 1                     0.351   31    False
# 2                     0.672   32     True
# 3                     0.167   21    False
# 4                     2.288   33     True

# %%
data.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %%
data.tail()
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 100            1      163             72              0        0  39.0
# 101            1      151             60              0        0  26.1
# 102            0      125             96              0        0  22.5
# 103            1       81             72             18       40  26.6
# 104            2       85             65              0        0  39.6
#
#      diabetespedigreefunction  age  outcome
# 100                     1.222   33     True
# 101                     0.179   22    False
# 102                     0.262   21    False
# 103                     0.283   24    False
# 104                     0.930   27    False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pregnancies               105 non-null    int64
#  1   glucose                   105 non-null    int64
#  2   bloodpressure             105 non-null    int64
#  3   skinthickness             105 non-null    int64
#  4   insulin                   105 non-null    int64
#  5   bmi                       105 non-null    float64
#  6   diabetespedigreefunction  105 non-null    float64
#  7   age                       105 non-null    int64
#  8   outcome                   105 non-null    bool
# dtypes: bool(1), float64(2), int64(6)
# memory usage: 6.8 KB

# %%
data.describe().T
# Out:
#                           count        mean         std     min     25%  \
# pregnancies               105.0    4.438095    3.589311   0.000   1.000
# glucose                   105.0  118.085714   33.703776   0.000  99.000
# bloodpressure             105.0   68.304762   21.669779   0.000  64.000
# skinthickness             105.0   19.123810   16.364064   0.000   0.000
# insulin                   105.0   71.190476  124.233426   0.000   0.000
# bmi                       105.0   30.984762    9.506939   0.000  25.400
# diabetespedigreefunction  105.0    0.473990    0.374390   0.102   0.248
# age                       105.0   33.990476   11.148901  21.000  25.000
#
#                               50%      75%      max
# pregnancies                 4.000    7.000   15.000
# glucose                   113.000  139.000  197.000
# bloodpressure              72.000   80.000  110.000
# skinthickness              20.000   32.000   60.000
# insulin                     0.000  110.000  846.000
# ...

# %%
data.isnull().sum()
# Out:
# pregnancies                 0
# glucose                     0
# bloodpressure               0
# skinthickness               0
# insulin                     0
# bmi                         0
# diabetespedigreefunction    0
# age                         0
# outcome                     0
# dtype: int64

# %%
data.dtypes
# Out:
# pregnancies                   int64
# glucose                       int64
# bloodpressure                 int64
# skinthickness                 int64
# insulin                       int64
# bmi                         float64
# diabetespedigreefunction    float64
# age                           int64
# outcome                        bool
# dtype: object

# %%
plt.scatter(data.index,data['pregnancies'])
plt.show()

# %%
plt.scatter(data.index,data['glucose'])
plt.show()

# %%
plt.scatter(data.index,data['bloodpressure'])
plt.show()

# %%
plt.scatter(data.index,data['skinthickness'])
plt.show()

# %%
plt.scatter(data.index,data['insulin'])
plt.show()

# %%
plt.scatter(data.index,data['bmi'])
plt.show()

# %%
plt.scatter(data.index,data['diabetespedigreefunction'])
plt.show()

# %%
plt.scatter(data.index,data['age'])
plt.show()

# %%
plt.scatter(data.index,data['outcome'])
plt.show()

# %%
sns.relplot(x='pregnancies',y='outcome',kind='line',data=data)

# %%
sns.relplot(x='glucose',y='bloodpressure',kind='line',data=data)

# %%
sns.relplot(x='skinthickness',y='insulin',kind='line',data=data)

# %%
sns.relplot(x='bmi',y='insulin',kind='line',data=data)

# %%
sns.relplot(x='diabetespedigreefunction',y='age',kind='line',data=data)

# %%
sns.relplot(x='age',y='glucose',kind='line',data=data)

# %%
sns.relplot(x='age',y='bloodpressure',kind='line',data=data)

# %%
sns.relplot(x='glucose',y='bloodpressure',hue='pregnancies',data=data)

# %%
sns.relplot(x='glucose',y='bloodpressure',hue='pregnancies',kind='line',data=data)

# %%
sns.relplot(x='skinthickness',y='insulin',hue='pregnancies',kind='line',data=data)

# %%
sns.relplot(x='bmi',y='insulin',hue='pregnancies',kind='line',data=data)

# %%
sns.relplot(x='diabetespedigreefunction',y='age',hue='pregnancies',kind='line',data=data)

# %%
sns.relplot(x='age',y='glucose',hue='pregnancies',kind='line',data=data)

# %%
sns.relplot(x='age',y='bloodpressure',hue='pregnancies',kind='line',data=data)
